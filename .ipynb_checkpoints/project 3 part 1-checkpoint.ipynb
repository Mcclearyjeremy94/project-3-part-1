# %%
import pandas as pd
import numpy as np

# %%
basics_url='https://datasets.imdbws.com/title.basics.tsv.gz'
title_url='https://datasets.imdbws.com/title.akas.tsv.gz'
title_ratings='https://datasets.imdbws.com/title.ratings.tsv.gz'

# %%
basics= pd.read_csv(basics_url, sep='\t', low_memory=False)

# %%
titlesakas= pd.read_csv(title_url, sep='\t', low_memory=False)

# %%
titleR= pd.read_csv(title_ratings, sep='\t', low_memory=False)

# %%
basics.replace({'\\N':np.nan},inplace=True)
basics.isna().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle           11
# originalTitle          11
# isAdult                 1
# startYear         1327682
# endYear           9700427
# runtimeMinutes    6917265
# genres             442042
# dtype: int64

# %%
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894     NaN              1         Documentary,Short
# 1       0      1892     NaN              5           Animation,Short
# 2       0      1892     NaN              4  Animation,Comedy,Romance
# 3       0      1892     NaN             12           Animation,Short
# 4       0      1893     NaN              1              Comedy,Short

# %%
basics= basics.dropna(subset=['runtimeMinutes','startYear', 'genres'])

# %%
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894     NaN              1         Documentary,Short
# 1       0      1892     NaN              5           Animation,Short
# 2       0      1892     NaN              4  Animation,Comedy,Romance
# 3       0      1892     NaN             12           Animation,Short
# 4       0      1893     NaN              1              Comedy,Short

# %%
basics.startYear= basics.startYear.astype(float)

# %%
basics = basics.loc[ basics['titleType']=='movie']

# %%
basics.head()
# Out:
#         tconst titleType                    primaryTitle  \
# 8    tt0000009     movie                      Miss Jerry
# 144  tt0000147     movie   The Corbett-Fitzsimmons Fight
# 570  tt0000574     movie     The Story of the Kelly Gang
# 587  tt0000591     movie                The Prodigal Son
# 672  tt0000679     movie  The Fairylogue and Radio-Plays
#
#                       originalTitle isAdult  startYear endYear runtimeMinutes  \
# 8                        Miss Jerry       0     1894.0     NaN             45
# 144   The Corbett-Fitzsimmons Fight       0     1897.0     NaN            100
# 570     The Story of the Kelly Gang       0     1906.0     NaN             70
# 587               L'enfant prodigue       0     1907.0     NaN             90
# 672  The Fairylogue and Radio-Plays       0     1908.0     NaN            120
#
#                          genres
# 8                       Romance
# 144      Documentary,News,Sport
# 570  Action,Adventure,Biography
# 587                       Drama
# 672           Adventure,Fantasy

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 368696 entries, 8 to 9525694
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          368696 non-null  object
#  1   titleType       368696 non-null  object
#  2   primaryTitle    368696 non-null  object
#  3   originalTitle   368696 non-null  object
#  4   isAdult         368696 non-null  object
#  5   startYear       368696 non-null  float64
#  6   endYear         0 non-null       object
#  7   runtimeMinutes  368696 non-null  object
#  8   genres          368696 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 28.1+ MB

# %%
basics = basics[(basics['startYear']>=2000)&(basics['startYear']<2022)]
basics
# Out:
#             tconst titleType  \
# 13082    tt0013274     movie
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 77964    tt0079644     movie
# ...            ...       ...
# 9525510  tt9916362     movie
# 9525594  tt9916538     movie
# 9525635  tt9916622     movie
# 9525662  tt9916680     movie
# 9525694  tt9916754     movie
#
#                                               primaryTitle  \
# 13082                          Istoriya grazhdanskoy voyny
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 77964                                        November 1828
# ...                                                    ...
# 9525510                                              Coven
# 9525594                                Kuambil Lagi Hatiku
# 9525635        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9525662  De la ilusión al desconcierto: cine colombiano...
# 9525694                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult  startYear  \
# 13082                          Istoriya grazhdanskoy voyny       0     2021.0
# 34803                                       Kate & Leopold       0     2001.0
# 61116            El Tango del Viudo y Su Espejo Deformante       0     2020.0
# 67669                           The Other Side of the Wind       0     2018.0
# 77964                                        November 1828       0     2001.0
# ...                                                    ...     ...        ...
# 9525510                                           Akelarre       0     2020.0
# 9525594                                Kuambil Lagi Hatiku       0     2019.0
# 9525635        Rodolpho Teóphilo - O Legado de um Pioneiro       0     2015.0
# 9525662  De la ilusión al desconcierto: cine colombiano...       0     2007.0
# 9525694                     Chico Albuquerque - Revelações       0     2013.0
#
#         endYear runtimeMinutes                  genres
# 13082       NaN            133             Documentary
# 34803       NaN            118  Comedy,Fantasy,Romance
# 61116       NaN             70                   Drama
# 67669       NaN            122                   Drama
# 77964       NaN            140               Drama,War
# ...         ...            ...                     ...
# 9525510     NaN             92           Drama,History
# 9525594     NaN            123                   Drama
# 9525635     NaN             57             Documentary
# 9525662     NaN            100             Documentary
# 9525694     NaN             49             Documentary
#
# [208876 rows x 9 columns]

# %%
# Exclude movies that are included in the documentary category.
is_documentary = basics['genres'].str.contains('documentary',case=False)
basics = basics[~is_documentary]

# %% [markdown]
# ## cleaning for akas

# %%
titlesakas.replace({'\\N':np.nan},inplace=True)
titlesakas.isna().sum()
# Out:
# titleId                   0
# ordering                  0
# title                     5
# region              1876176
# language            6467848
# types              29093234
# attributes         34283313
# isOriginalTitle        2109
# dtype: int64

# %%
titlesakas=titlesakas[titlesakas.region=="US"]

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers =basics['tconst'].isin(titlesakas['titleId'])
keepers
# Out:
# 34803       True
# 61116       True
# 67669       True
# 77964      False
# 86801       True
#            ...
# 9525417     True
# 9525426     True
# 9525465    False
# 9525510     True
# 9525594    False
# Name: tconst, Length: 137542, dtype: bool

# %%
basics = basics[keepers]
basics
# Out:
#             tconst titleType  \
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 86801    tt0088751     movie
# 93938    tt0096056     movie
# ...            ...       ...
# 9524881  tt9914942     movie
# 9525277  tt9915872     movie
# 9525417  tt9916170     movie
# 9525426  tt9916190     movie
# 9525510  tt9916362     movie
#
#                                               primaryTitle  \
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 86801                                    The Naked Monster
# 93938                                 Crime and Punishment
# ...                                                    ...
# 9524881                             Life Without Sara Amat
# 9525277                               The Last White Witch
# 9525417                                      The Rehearsal
# 9525426                                          Safeguard
# 9525510                                              Coven
#
#                                      originalTitle isAdult  startYear endYear  \
# 34803                               Kate & Leopold       0     2001.0     NaN
# 61116    El Tango del Viudo y Su Espejo Deformante       0     2020.0     NaN
# 67669                   The Other Side of the Wind       0     2018.0     NaN
# 86801                            The Naked Monster       0     2005.0     NaN
# 93938                         Crime and Punishment       0     2002.0     NaN
# ...                                            ...     ...        ...     ...
# 9524881                 La vida sense la Sara Amat       0     2019.0     NaN
# 9525277                  My Girlfriend is a Wizard       0     2019.0     NaN
# 9525417                                   O Ensaio       0     2019.0     NaN
# 9525426                                  Safeguard       0     2020.0     NaN
# 9525510                                   Akelarre       0     2020.0     NaN
#
#         runtimeMinutes                     genres
# 34803              118     Comedy,Fantasy,Romance
# 61116               70                      Drama
# 67669              122                      Drama
# 86801              100       Comedy,Horror,Sci-Fi
# 93938              126                      Drama
# ...                ...                        ...
# 9524881             74                      Drama
# 9525277             97       Comedy,Drama,Fantasy
# 9525417             51                      Drama
# 9525426             95  Action,Adventure,Thriller
# 9525510             92              Drama,History
#
# [80432 rows x 9 columns]

# %%
titleR.replace({'\\N':np.nan},inplace=True)
titleR.isna().sum()
# Out:
# tconst           0
# averageRating    0
# numVotes         0
# dtype: int64

# %%
keepers = titleR['tconst'].isin(titlesakas['titleId'])
ratings = titleR[keepers]
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1939
# 1        tt0000002            5.8       262
# 4        tt0000005            6.2      2572
# 5        tt0000006            5.1       177
# 6        tt0000007            5.4       808
# ...            ...            ...       ...
# 1267315  tt9916200            8.2       220
# 1267316  tt9916204            8.2       251
# 1267322  tt9916348            8.5        17
# 1267323  tt9916362            6.4      5110
# 1267327  tt9916428            3.8        14
#
# [485155 rows x 3 columns]

# %%
# example making new folder with os
import os
os.makedirs('Data/',exist_ok=True) 
# Confirm folder created
os.listdir("Data/")
# Out:
# ['tmdb_api_results_2000.json',
#  'final_tmdb_data_2000.csv.gz',
#  'tmdb_api_results_2001.json',
#  'title_basics.csv.gz',
#  'final_tmdb_data_2001.csv.gz',
#  'title_akas.csv.gz',
#  'titleR.csv.gz']

# %%
## Save current dataframe to file.
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)

# %%
## Save current dataframe to file.
titlesakas.to_csv("Data/title_akas.csv.gz",compression='gzip',index=False)

# %%
## Save current dataframe to file.
ratings.to_csv("Data/titleR.csv.gz",compression='gzip',index=False)

# %%
def get_movie_with_rating(movie_id):
    """Adapted from source = https://github.com/celiao/tmdbsimple"""
    #Get the movie object for the current id
    movie = tmdb.Movies(movie_id)
    
    #save the info releases dictionaries
    info = movie.info()
    releases = movie.releases()
    
    #Loop through countries in releases
    for c in releases ['countries']:
        #if the country abbreviation==Us
        if c['iso_3166_1'] =='US':
##save a "certification" key in info with the certification
            info ['certification'] = c['certification']
    return info
